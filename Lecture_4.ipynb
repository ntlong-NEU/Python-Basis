# %% [markdown]
# ### **Lecture 4: While loops**

# %%
numbers = [1,2,3,4,2,1,2,2,1,2,1]
while 1 in numbers:
    numbers.remove(1)
print(numbers)
# Out:
# [2, 3, 4, 2, 2, 2, 2]

# %%
bool([])
# Out:
# False

# %%
bool([1,2,3])
# Out:
# True

# %%
alist = [32,2,34,2,3,42,34,234,23]
blist = []
while alist:
    item = alist.pop()
    blist.append(item)
print(alist)
print(blist)
# Out:
# []
# [23, 234, 34, 42, 3, 2, 34, 2, 32]
