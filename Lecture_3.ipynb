# %% [markdown]
# ## **Lecture 3**: Lists, Tuples, Sets and Dictionaries

# %% [markdown]
# **Defining a list**: Use square brackets ([]) to define a list, and use commas to separate individual items in the list.

# %%
cars = ['Merc','Toy','Huyndai','Kia']
print(cars)
# Out:
# ['Merc', 'Toy', 'Huyndai', 'Kia']

# %%
len(cars)
# Out:
# 4

# %%
cars[0]
# Out:
# 'Merc'

# %%
cars[2]
# Out:
# 'Huyndai'

# %%
cars[-1]
# Out:
# 'Kia'

# %%
cars[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cars[4]
#
# IndexError: list index out of range

# %% [markdown]
# **3-1. Names:** Store the names of a few of your friends in a list called names. Print
# each person’s name by accessing each element in the list, one at a time.

# %% [markdown]
# **3-2. Greetings:** Start with the list you used in Exercise 3-1, but instead of just
# printing each person’s name, print a message to them. The text of each message should be the same, but each message should be personalized with the
# person’s name.

# %% [markdown]
# **3-3. Your Own List:** Think of your favorite mode of transportation, such as a
# motorcycle or a car, and make a list that stores several examples. Use your list
# to print a series of statements about these items, such as “I would like to own a
# Honda motorcycle.”

# %%
cars
# Out:
# ['Merc', 'Toy', 'Huyndai', 'Kia']

# %%
cars[0] = 'new car'
cars
# Out:
# ['new car', 'Toy', 'Huyndai', 'Kia']

# %%
cars.append('BMW')
cars
# Out:
# ['new car', 'Toy', 'Huyndai', 'Kia', 'BMW']

# %%
cars.append('Toy')

# %%
cars
# Out:
# ['new car', 'Toy', 'Huyndai', 'Kia', 'BMW', 'Toy']

# %%
cars.insert(1,'insert_object')
cars
# Out:
# ['new car',
#  'insert_object',
#  'insert_object',
#  'Toy',
#  'Huyndai',
#  'Kia',
#  'BMW',
#  'Toy']

# %%
del cars[2]
cars
# Out:
# ['new car', 'insert_object', 'Huyndai', 'Kia', 'BMW', 'Toy']

# %%
cars.pop()
# Out:
# 'Toy'

# %%
cars.append('insert_object') 
cars
# Out:
# ['new car', 'Huyndai', 'Kia', 'BMW', 'insert_object']

# %%
cars.remove('insert_object')
cars
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cars.remove('insert_object')
#       2 cars
#
# ValueError: list.remove(x): x not in list

# %%
try:
    cars.remove('insert_object')
except ValueError:
    pass

# %%
numbers = [2,1,4,6,8,2,3]
print(sorted(numbers))
print(numbers)
# Out:
# [1, 2, 2, 3, 4, 6, 8]
# [2, 1, 4, 6, 8, 2, 3]

# %%
numbers = [2,1,4,6,8,2,3]
print(numbers.sort())
print(numbers)
# Out:
# None
# [1, 2, 2, 3, 4, 6, 8]

# %%
numbers = [2,1,4,6,8,2,3]
sorted(numbers, reverse=True)
# Out:
# [8, 6, 4, 3, 2, 2, 1]

# %%
numbers = [2,1,4,6,8,2,3]
sorted(numbers, key = lambda x: x%3)
# Out:
# [6, 3, 1, 4, 2, 8, 2]

# %%
words = ['aff', 'sfsf', 'cde','0qwe','aca']
sorted(words)
# Out:
# ['0qwe', 'aca', 'aff', 'cde', 'sfsf']

# %%
words = ['aff', 'sfsf', 'cde','0qwe','aca']
sorted(words, key  = lambda x: len(x))
# Out:
# ['aff', 'cde', 'aca', 'sfsf', '0qwe']

# %%
numbers
# Out:
# [2, 1, 4, 6, 8, 2, 3]

# %%
numbers.reverse()

# %%
numbers
# Out:
# [3, 2, 8, 6, 4, 1, 2]

# %%
dir(numbers)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
numbers = [2,1,4,6,8,2,3,1,1,1]
numbers.count(1)
# Out:
# 4

# %%
numbers = [2,1,4,6,8,2,3,1,1,1]
for n in numbers:
    print('n+1 = ', n+1)
    print('----')
print('end')
# Out:
# n+1 =  3
# ----
# n+1 =  2
# ----
# n+1 =  5
# ----
# n+1 =  7
# ----
# n+1 =  9
# ----
# n+1 =  3
# ----
# n+1 =  4
# ----
# n+1 =  2
# ----
# n+1 =  2
# ----
# n+1 =  2
# ----
# end

# %%
message = 'Hello python'
for letter in message:
    print(letter.upper())
# Out:
# H
# E
# L
# L
# O
#
# P
# Y
# T
# H
# O
# N

# %%
numbers = [2,1,4,6,8,2,3,1,1,1]
for i in numbers:
    pass

# %%
list(range(4))
# Out:
# [0, 1, 2, 3]

# %%
numbers = [2,1,4,6,8,2,3,1,1,1]
for _ in range(numbers.count(1)):
    numbers.remove(1)
print(numbers)
# Out:
# [2, 4, 6, 8, 2, 3]

# %%
square_10 = []
for i in range(1,11):
    square_10.append(i**2)
print(square_10)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares = []
for i in range(1,20,2):
    squares.append(i**2)

print(squares)
# Out:
# [1, 9, 25, 49, 81, 121, 169, 225, 289, 361]

# %%
[i**2 for i in range(1,10)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
[i**2 for i in range(1,100) if i%9==0]
# Out:
# [81, 324, 729, 1296, 2025, 2916, 3969, 5184, 6561, 8100, 9801]

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!'''

# %%
text_nor = text.lower()
special_chars = {'.',',', '!',':','*','-'}
for char in special_chars:
    text_nor = text_nor.replace(char, ' ')
print(text_nor)
# Out:
# the zen of python  by tim peters
#
# beautiful is better than ugly
# explicit is better than implicit
# simple is better than complex
# complex is better than complicated
# flat is better than nested
# sparse is better than dense
# readability counts
# special cases aren't special enough to break the rules
# although practicality beats purity
# errors should never pass silently
# unless explicitly silenced
# in the face of ambiguity  refuse the temptation to guess
# there should be one   and preferably only one   obvious way to do it
# although that way may not be obvious at first unless you're dutch
# now is better than never
# although never is often better than  right  now
# if the implementation is hard to explain  it's a bad idea
# if the implementation is easy to explain  it may be a good idea
# namespaces are one honking great idea    let's do more of those

# %%
words = text_nor.split()
word_unique = set(words)
fre_word = []
for w in word_unique:
    fre_word.append((w,words.count(w)))
print(fre_word)
# Out:
# [('flat', 1), ('python', 1), ('idea', 3), ('dutch', 1), ('may', 2), ('hard', 1), ('that', 1), ('obvious', 2), ('enough', 1), ('zen', 1), ('at', 1), ('ambiguity', 1), ('now', 2), ("you're", 1), ('unless', 2), ('explicitly', 1), ('refuse', 1), ('rules', 1), ('implicit', 1), ('a', 2), ('although', 3), ('ugly', 1), ('sparse', 1), ('first', 1), ('silently', 1), ('errors', 1), ('the', 6), ('never', 3), ("it's", 1), ('dense', 1), ('be', 3), ('preferably', 1), ('good', 1), ("aren't", 1), ('by', 1), ('temptation', 1), ('readability', 1), ('special', 2), ('one', 3), ('guess', 1), ('only', 1), ('and', 1), ('more', 1), ('of', 3), ('better', 8), ('complicated', 1), ('easy', 1), ('not', 1), ('cases', 1), ('pass', 1), ('namespaces', 1), ('implementation', 2), ('great', 1), ('complex', 2), ('it', 2), ('in', 1), ('honking', 1), ('way', 2), ('counts', 1), ("let's", 1), ('those', 1), ('should', 2), ('nested', 1), ('right', 1), ('silenced', 1), ('practicality', 1), ('face', 1), ('beats', 1), ('tim', 1),
# ...

# %%
sorted(fre_word, key = lambda x: x[1], reverse= True)
# Out:
# [('is', 10),
#  ('better', 8),
#  ('than', 8),
#  ('the', 6),
#  ('to', 5),
#  ('idea', 3),
#  ('although', 3),
#  ('never', 3),
#  ('be', 3),
#  ('one', 3),
#  ('of', 3),
#  ('may', 2),
#  ('obvious', 2),
#  ('now', 2),
#  ('unless', 2),
#  ('a', 2),
#  ('special', 2),
#  ('implementation', 2),
#  ('complex', 2),
#  ('it', 2),
#  ('way', 2),
#  ('should', 2),
#  ('explain', 2),
#  ('if', 2),
#  ('do', 2),
#  ('flat', 1),
#  ('python', 1),
#  ('dutch', 1),
#  ('hard', 1),
#  ('that', 1),
#  ('enough', 1),
#  ('zen', 1),
#  ('at', 1),
#  ('ambiguity', 1),
#  ("you're", 1),
#  ('explicitly', 1),
#  ('refuse', 1),
#  ('rules', 1),
#  ('implicit', 1),
#  ('ugly', 1),
#  ('sparse', 1),
#  ('first', 1),
#  ('silently', 1),
#  ('errors', 1),
#  ("it's", 1),
#  ('dense', 1),
#  ('preferably', 1),
#  ('good', 1),
#  ("aren't", 1),
#  ('by', 1),
#  ('temptation', 1),
#  ('readability', 1),
#  ('guess', 1),
#  ('only', 1),
#  ('and', 1),
#  ('more', 1),
#  ('complicated', 1),
#  ('easy', 1),
# ...

# %%
scores = {'Hoang':9, "Lan":10, 'Mai':9}
type(scores)
# Out:
# dict

# %%
scores = {'Hoang':9, "Lan":10, 'Mai':9, 'Mai':9}
print(scores)
# Out:
# {'Hoang': 9, 'Lan': 10, 'Mai': 9}

# %%
scores = {'Hoang':9, "Lan":10, 'Mai':9, 'Mai':10}
print(scores)
# Out:
# {'Hoang': 9, 'Lan': 10, 'Mai': 10}

# %%
scores['Hoang']
# Out:
# 9

# %%
scores = {'Hoang':9, "Lan":10, 'Mai':9, ('Mai','Hoa'):10}

# %%
scores['Hoang'] = 9.5
scores
# Out:
# {'Hoang': 9.5, 'Lan': 10, 'Mai': 9, ('Mai', 'Hoa'): 10}

# %%
scores['Ha'] = 8
scores
# Out:
# {'Hoang': 9.5, 'Lan': 10, 'Mai': 9, ('Mai', 'Hoa'): 10, 'Ha': 8}

# %%
del scores[('Mai', 'Hoa')]
scores
# Out:
# {'Hoang': 9.5, 'Lan': 10, 'Mai': 9, 'Ha': 8}

# %%
fre_word
# Out:
# [('flat', 1),
#  ('python', 1),
#  ('idea', 3),
#  ('dutch', 1),
#  ('may', 2),
#  ('hard', 1),
#  ('that', 1),
#  ('obvious', 2),
#  ('enough', 1),
#  ('zen', 1),
#  ('at', 1),
#  ('ambiguity', 1),
#  ('now', 2),
#  ("you're", 1),
#  ('unless', 2),
#  ('explicitly', 1),
#  ('refuse', 1),
#  ('rules', 1),
#  ('implicit', 1),
#  ('a', 2),
#  ('although', 3),
#  ('ugly', 1),
#  ('sparse', 1),
#  ('first', 1),
#  ('silently', 1),
#  ('errors', 1),
#  ('the', 6),
#  ('never', 3),
#  ("it's", 1),
#  ('dense', 1),
#  ('be', 3),
#  ('preferably', 1),
#  ('good', 1),
#  ("aren't", 1),
#  ('by', 1),
#  ('temptation', 1),
#  ('readability', 1),
#  ('special', 2),
#  ('one', 3),
#  ('guess', 1),
#  ('only', 1),
#  ('and', 1),
#  ('more', 1),
#  ('of', 3),
#  ('better', 8),
#  ('complicated', 1),
#  ('easy', 1),
#  ('not', 1),
#  ('cases', 1),
#  ('pass', 1),
#  ('namespaces', 1),
#  ('implementation', 2),
#  ('great', 1),
#  ('complex', 2),
#  ('it', 2),
#  ('in', 1),
#  ('honking', 1),
# ...

# %%
for w,fre in fre_word:
    print(w,fre)
# Out:
# flat 1
# python 1
# idea 3
# dutch 1
# may 2
# hard 1
# that 1
# obvious 2
# enough 1
# zen 1
# at 1
# ambiguity 1
# now 2
# you're 1
# unless 2
# explicitly 1
# refuse 1
# rules 1
# implicit 1
# a 2
# although 3
# ugly 1
# sparse 1
# first 1
# silently 1
# errors 1
# the 6
# never 3
# it's 1
# dense 1
# be 3
# preferably 1
# good 1
# aren't 1
# by 1
# temptation 1
# readability 1
# special 2
# one 3
# guess 1
# only 1
# and 1
# more 1
# of 3
# better 8
# complicated 1
# easy 1
# not 1
# cases 1
# pass 1
# namespaces 1
# implementation 2
# great 1
# complex 2
# it 2
# in 1
# honking 1
# way 2
# counts 1
# let's 1
# those 1
# should 2
# nested 1
# right 1
# silenced 1
# practicality 1
# face 1
# beats 1
# tim 1
# bad 1
# simple 1
# peters 1
# explain 2
# if 2
# do 2
# is 10
# explicit 1
# than 8
# break 1
# to 5
# purity 1
# there 1
# often 1
# are 1
# beautiful 1

# %%
for key,value  in scores.items():
    print('Key: ', key, 'and value:', value)
# Out:
# Key:  Hoang and value: 9.5
# Key:  Lan and value: 10
# Key:  Mai and value: 9
# Key:  Ha and value: 8

# %%
scores.keys()
# Out:
# dict_keys(['Hoang', 'Lan', 'Mai', 'Ha'])

# %%
scores.values()
# Out:
# dict_values([9.5, 10, 9, 8])

# %%
list(zip(scores.keys(),scores.values()))
# Out:
# [('Hoang', 9.5), ('Lan', 10), ('Mai', 9), ('Ha', 8)]

# %%
age = int(input('How old are you?'))
discount = 0.25
if age<10:
    discount = 0.15
elif age<18:
    discount = 0.08
elif age<23:
    discount = 0.05
elif age<=60:
    discount = 0.02
price = 100
print(price*(1-discount))
# Out:
# 98.0

# %%
for i in range(10):
    print(i)
    if i==5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
